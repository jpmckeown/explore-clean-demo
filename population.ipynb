# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %%
import pycountry
import pypopulation

# %%
import plotly
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 import plotly
#
# ModuleNotFoundError: No module named 'plotly'

# %%
import wbgapi as wba
import world_bank_data as wb

# %%
population = wb.get_series('SP.POP.TOTL', mrv=1)
population
# Out:
# Country                         Series             Year
# Africa Eastern and Southern     Population, total  2022    720839314.0
# Africa Western and Central      Population, total  2022    490330870.0
# Arab World                      Population, total  2022    464684914.0
# Caribbean small states          Population, total  2022      7505478.0
# Central Europe and the Baltics  Population, total  2022    100648571.0
#                                                               ...
# Virgin Islands (U.S.)           Population, total  2022       105413.0
# West Bank and Gaza              Population, total  2022      5043612.0
# Yemen, Rep.                     Population, total  2022     33696614.0
# Zambia                          Population, total  2022     20017675.0
# Zimbabwe                        Population, total  2022     16320537.0
# Name: SP.POP.TOTL, Length: 266, dtype: float64

# %%
# Same data set, indexed with the country code
population = wb.get_series('SP.POP.TOTL', id_or_value='id', simplify_index=True, mrv=1)
population
# Out:
# Country
# AFE    720839314.0
# AFW    490330870.0
# ARB    464684914.0
# CSS      7505478.0
# CEB    100648571.0
#           ...
# VIR       105413.0
# PSE      5043612.0
# YEM     33696614.0
# ZMB     20017675.0
# ZWE     16320537.0
# Name: SP.POP.TOTL, Length: 266, dtype: float64

# %%
wb.search_indicators("population")
# Out:
#                                                                             name  \
# id
# 1.0.HCount.1.90usd                               Poverty Headcount ($1.90 a day)
# 1.0.HCount.2.5usd                                Poverty Headcount ($2.50 a day)
# 1.0.HCount.Mid10to50                       Middle Class ($10-50 a day) Headcount
# 1.0.HCount.Ofcl                          Official Moderate Poverty Rate-National
# 1.0.HCount.Poor4uds                                 Poverty Headcount ($4 a day)
# ...                                                                          ...
# UIS.YADULT.PROFINUMERACY.M     Proportion of population achieving at least a ...
# UIS.YADULT.PROFINUMERACY.NAT   Proportion of population achieving at least a ...
# UIS.YADULT.PROFINUMERACY.NON   Proportion of population achieving at least a ...
# UIS.YADULT.PROFINUMERACY.NPIA  Proportion of population achieving at least a ...
# UIS.YADULT.PROFINUMERACY.WPIA  Proportion of population achieving at least a ...
#
#                               unit                source  \
# id
# 1.0.HCount.1.90usd                        LAC Equity Lab
# 1.0.HCount.2.5usd                         LAC Equity Lab
# 1.0.HCount.Mid10to50                      LAC Equity Lab
# 1.0.HCount.Ofcl                           LAC Equity Lab
# 1.0.HCount.Poor4uds                       LAC Equity Lab
# ...                            ...                   ...
# UIS.YADULT.PROFINUMERACY.M          Education Statistics
# UIS.YADULT.PROFINUMERACY.NAT        Education Statistics
# UIS.YADULT.PROFINUMERACY.NON        Education Statistics
# UIS.YADULT.PROFINUMERACY.NPIA       Education Statistics
# UIS.YADULT.PROFINUMERACY.WPIA       Education Statistics
#
#                                                                       sourceNote  \
# id
# 1.0.HCount.1.90usd             The poverty headcount index measures the propo...
# 1.0.HCount.2.5usd              The poverty headcount index measures the propo...
# 1.0.HCount.Mid10to50           The poverty headcount index measures the propo...
# 1.0.HCount.Ofcl                The poverty headcount index measures the propo...
# 1.0.HCount.Poor4uds            The poverty headcount index measures the propo...
# ...                                                                          ...
# UIS.YADULT.PROFINUMERACY.M     The percentage of male youth and adults (15 ye...
# UIS.YADULT.PROFINUMERACY.NAT   The percentage of non-immigrant youth and adul...
# UIS.YADULT.PROFINUMERACY.NON   The percentage of immigrant youth and adults (...
# UIS.YADULT.PROFINUMERACY.NPIA  The Adjusted Native Parity Index (NPIA) is cal...
# UIS.YADULT.PROFINUMERACY.WPIA  The Adjusted Wealth Parity Index (WPIA) is cal...
#
#                                                               sourceOrganization  \
# id
# 1.0.HCount.1.90usd             LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 1.0.HCount.2.5usd              LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 1.0.HCount.Mid10to50           LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# 1.0.HCount.Ofcl                LAC Equity Lab tabulations of data from Nation...
# 1.0.HCount.Poor4uds            LAC Equity Lab tabulations of SEDLAC (CEDLAS a...
# ...                                                                          ...
# UIS.YADULT.PROFINUMERACY.M                       UNESCO Institute for Statistics
# UIS.YADULT.PROFINUMERACY.NAT                     UNESCO Institute for Statistics
# UIS.YADULT.PROFINUMERACY.NON                     UNESCO Institute for Statistics
# UIS.YADULT.PROFINUMERACY.NPIA                    UNESCO Institute for Statistics
# UIS.YADULT.PROFINUMERACY.WPIA                    UNESCO Institute for Statistics
#
#                                  topics
# id
# 1.0.HCount.1.90usd             Poverty
# 1.0.HCount.2.5usd              Poverty
# 1.0.HCount.Mid10to50           Poverty
# 1.0.HCount.Ofcl                Poverty
# 1.0.HCount.Poor4uds            Poverty
# ...                                 ...
# UIS.YADULT.PROFINUMERACY.M
# UIS.YADULT.PROFINUMERACY.NAT
# UIS.YADULT.PROFINUMERACY.NON
# UIS.YADULT.PROFINUMERACY.NPIA
# UIS.YADULT.PROFINUMERACY.WPIA
#
# [5772 rows x 6 columns]

# %%
wb.get_countries()
# Out:
#     iso2Code                                               name  \
# id
# ABW       AW                                              Aruba
# AFE       ZH                        Africa Eastern and Southern
# AFG       AF                                        Afghanistan
# AFR       A9                                             Africa
# AFW       ZI                         Africa Western and Central
# ..       ...                                                ...
# XZN       A5  Sub-Saharan Africa excluding South Africa and ...
# YEM       YE                                        Yemen, Rep.
# ZAF       ZA                                       South Africa
# ZMB       ZM                                             Zambia
# ZWE       ZW                                           Zimbabwe
#
#                          region  \
# id
# ABW  Latin America & Caribbean
# AFE                  Aggregates
# AFG                  South Asia
# AFR                  Aggregates
# AFW                  Aggregates
# ..                          ...
# XZN                  Aggregates
# YEM  Middle East & North Africa
# ZAF         Sub-Saharan Africa
# ZMB         Sub-Saharan Africa
# ZWE         Sub-Saharan Africa
#
#                                            adminregion          incomeLevel  \
# id
# ABW                                                             High income
# AFE                                                              Aggregates
# AFG                                         South Asia           Low income
# AFR                                                              Aggregates
# AFW                                                              Aggregates
# ..                                                 ...                  ...
# XZN                                                              Aggregates
# YEM  Middle East & North Africa (excluding high inc...           Low income
# ZAF         Sub-Saharan Africa (excluding high income)  Upper middle income
# ZMB         Sub-Saharan Africa (excluding high income)  Lower middle income
# ZWE         Sub-Saharan Africa (excluding high income)  Lower middle income
#
#         lendingType capitalCity  longitude  latitude
# id
# ABW  Not classified  Oranjestad   -70.0167   12.5167
# AFE      Aggregates                    NaN       NaN
# AFG             IDA       Kabul    69.1761   34.5228
# AFR      Aggregates                    NaN       NaN
# AFW      Aggregates                    NaN       NaN
# ..              ...         ...        ...       ...
# XZN      Aggregates                    NaN       NaN
# YEM             IDA      Sana'a    44.2075   15.3520
# ZAF            IBRD    Pretoria    28.1871  -25.7460
# ZMB             IDA      Lusaka    28.2937  -15.3982
# ZWE           Blend      Harare    31.0672  -17.8312
#
# [297 rows x 9 columns]

# %%
pypopulation.get_population("DE")
# Out:
# 83132799

# %%
df = pd.read_csv("https://github.com/AlexTheAnalyst/PandasYouTubeSeries/blob/main/world_population.csv")
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# Cell In[5], line 1
# ----> 1 df = pd.read_csv("https://github.com/AlexTheAnalyst/PandasYouTubeSeries/blob/main/world_population.csv")
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/io/parsers/readers.py:912, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     899 kwds_defaults = _refine_defaults_read(
#     900     dialect,
#     901     delimiter,
#    (...)
#     908     dtype_backend=dtype_backend,
#     909 )
#     910 kwds.update(kwds_defaults)
# --> 912 return _read(filepath_or_buffer, kwds)
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/io/parsers/readers.py:583, in _read(filepath_or_buffer, kwds)
#     580     return parser
#     582 with parser:
# --> 583     return parser.read(nrows)
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1704, in TextFileReader.read(self, nrows)
#    1697 nrows = validate_integer("nrows", nrows)
#    1698 try:
#    1699     # error: "ParserBase" has no attribute "read"
#    1700     (
#    1701         index,
#    1702         columns,
#    1703         col_dict,
# -> 1704     ) = self._engine.read(  # type: ignore[attr-defined]
#    1705         nrows
#    1706     )
#    1707 except Exception:
#    1708     self.close()
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:234, in CParserWrapper.read(self, nrows)
#     232 try:
#     233     if self.low_memory:
# --> 234         chunks = self._reader.read_low_memory(nrows)
#     235         # destructive to chunks
#     236         data = _concatenate_chunks(chunks)
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:814, in pandas._libs.parsers.TextReader.read_low_memory()
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:875, in pandas._libs.parsers.TextReader._read_rows()
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:850, in pandas._libs.parsers.TextReader._tokenize_rows()
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:861, in pandas._libs.parsers.TextReader._check_tokenize_status()
#
# File ~/miniconda3/envs/io-ds/lib/python3.11/site-packages/pandas/_libs/parsers.pyx:2029, in pandas._libs.parsers.raise_parser_error()
#
# ParserError: Error tokenizing data. C error: Expected 1 fields in line 32, saw 6
